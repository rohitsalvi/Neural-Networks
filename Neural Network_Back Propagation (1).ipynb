# %%
# Create your first MLP in Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load pima indians dataset
dataset = numpy.loadtxt("C:/Users/ROHIT/anaconda3/projects/pima-indians-diabetes.data.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2)

# %%
# Fit the model
history = model.fit(x_train, y_train,batch_size=10,validation_data=(x_test, y_test),epochs = 20)
# Out:
# Epoch 1/20
# 62/62 [==============================] - 2s 9ms/step - loss: 0.6829 - accuracy: 0.6173 - val_loss: 0.6726 - val_accuracy: 0.6299
# Epoch 2/20
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6625 - accuracy: 0.6564 - val_loss: 0.6649 - val_accuracy: 0.6299
# Epoch 3/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6585 - accuracy: 0.6564 - val_loss: 0.6623 - val_accuracy: 0.6299
# Epoch 4/20
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6506 - accuracy: 0.6564 - val_loss: 0.6476 - val_accuracy: 0.6234
# Epoch 5/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6456 - accuracy: 0.6580 - val_loss: 0.6366 - val_accuracy: 0.6494
# Epoch 6/20
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6374 - accuracy: 0.6466 - val_loss: 0.6228 - val_accuracy: 0.6364
# Epoch 7/20
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6289 - accuracy: 0.6580 - val_loss: 0.6408 - val_accuracy: 0.6169
# Epoch 8/20
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6201 - accuracy: 0.6710 - val_loss: 0.6018 - val_accuracy: 0.6688
# Epoch 9/20
# 62/62 [==============================] - 0s 6ms/step - loss: 0.6214 - accuracy: 0.6743 - val_loss: 0.6005 - val_accuracy: 0.7338
# Epoch 10/20
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6043 - accuracy: 0.6922 - val_loss: 0.5838 - val_accuracy: 0.7143
# Epoch 11/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6008 - accuracy: 0.6775 - val_loss: 0.5821 - val_accuracy: 0.7338
# Epoch 12/20
# 62/62 [==============================] - 0s 6ms/step - loss: 0.6001 - accuracy: 0.6873 - val_loss: 0.5755 - val_accuracy: 0.7597
# Epoch 13/20
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5972 - accuracy: 0.7003 - val_loss: 0.5737 - val_accuracy: 0.7597
# Epoch 14/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5963 - accuracy: 0.6710 - val_loss: 0.5739 - val_accuracy: 0.7468
# Epoch 15/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5983 - accuracy: 0.6857 - val_loss: 0.5681 - val_accuracy: 0.7468
# Epoch 16/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5862 - accuracy: 0.6954 - val_loss: 0.5675 - val_accuracy: 0.7597
# Epoch 17/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5865 - accuracy: 0.7003 - val_loss: 0.5931 - val_accuracy: 0.6818
# Epoch 18/20
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5835 - accuracy: 0.6857 - val_loss: 0.5734 - val_accuracy: 0.7078
# Epoch 19/20
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5899 - accuracy: 0.7020 - val_loss: 0.5867 - val_accuracy: 0.7078
# Epoch 20/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5800 - accuracy: 0.7052 - val_loss: 0.5689 - val_accuracy: 0.7143

# %%
# evaluate the model
scores = model.evaluate(x_train, y_train)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5796 - accuracy: 0.6938
# accuracy: 69.38%

# %%
# Visualize training history

# list all data in history
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for accuracy
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
