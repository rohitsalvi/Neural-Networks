# %%
# Importing the necessary packages
import pandas as pd
import numpy as np
import keras
from sklearn.preprocessing import StandardScaler

# %%
# load pima indians dataset
dataset = np.loadtxt("C:/Users/ROHIT/anaconda3/projects/pima-indians-diabetes.data.csv", delimiter=",")

# %%
X = dataset[:,0:8]
y = dataset[:,8]

# %%
# Standardization
a = StandardScaler()
a.fit(X)
X_standardized = a.transform(X)

# %%
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1             2             3             4  \
# count  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02
# mean  -8.789266e-17 -9.251859e-18  1.503427e-17  8.211024e-17 -4.972874e-17
# std    1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00
# min   -1.141852e+00 -3.783654e+00 -3.572597e+00 -1.288212e+00 -6.928906e-01
# 25%   -8.448851e-01 -6.852363e-01 -3.673367e-01 -1.288212e+00 -6.928906e-01
# 50%   -2.509521e-01 -1.218877e-01  1.496408e-01  1.545332e-01 -4.280622e-01
# 75%    6.399473e-01  6.057709e-01  5.632228e-01  7.190857e-01  4.120079e-01
# max    3.906578e+00  2.444478e+00  2.734528e+00  4.921866e+00  6.652839e+00
#
#                   5             6             7
# count  7.680000e+02  7.680000e+02  7.680000e+02
# mean   2.960595e-15  1.905883e-15  2.081668e-16
# std    1.000652e+00  1.000652e+00  1.000652e+00
# min   -4.060474e+00 -1.189553e+00 -1.041549e+00
# 25%   -5.955785e-01 -6.889685e-01 -7.862862e-01
# 50%    9.419788e-04 -3.001282e-01 -3.608474e-01
# 75%    5.847705e-01  4.662269e-01  6.602056e-01
# max    4.455807e+00  5.883565e+00  4.063716e+00

# %% [markdown]
# #### Tuning of Hyperparameters :- Batch Size and Epochs

# %%
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import adam_v2

# %%
# create model
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
    
    optimizer = adam_v2.Adam(learning_rate=0.1)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
# Create the model
model = KerasClassifier(build_fn = create_model,verbose = 0)
# Define the grid search parameters
batch_size = [10,20,40]
epochs = [10,50,100]
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 1/5; 1/9] END .....batch_size=10, epochs=10;, score=0.701 total time=   3.3s
# [CV 2/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 2/5; 1/9] END .....batch_size=10, epochs=10;, score=0.682 total time=   2.0s
# [CV 3/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 3/5; 1/9] END .....batch_size=10, epochs=10;, score=0.688 total time=   2.1s
# [CV 4/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 4/5; 1/9] END .....batch_size=10, epochs=10;, score=0.804 total time=   2.1s
# [CV 5/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 5/5; 1/9] END .....batch_size=10, epochs=10;, score=0.732 total time=   2.3s
# [CV 1/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 1/5; 2/9] END .....batch_size=10, epochs=50;, score=0.649 total time=   7.9s
# [CV 2/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 2/5; 2/9] END .....batch_size=10, epochs=50;, score=0.584 total time=   9.8s
# [CV 3/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 3/5; 2/9] END .....batch_size=10, epochs=50;, score=0.669 total time=   6.0s
# [CV 4/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 4/5; 2/9] END .....batch_size=10, epochs=50;, score=0.725 total time=   5.9s
# [CV 5/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 5/5; 2/9] END .....batch_size=10, epochs=50;, score=0.732 total time=   6.0s
# [CV 1/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 1/5; 3/9] END ....batch_size=10, epochs=100;, score=0.753 total time=  10.6s
# [CV 2/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 2/5; 3/9] END ....batch_size=10, epochs=100;, score=0.688 total time=  16.9s
# [CV 3/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 3/5; 3/9] END ....batch_size=10, epochs=100;, score=0.753 total time=  10.2s
# [CV 4/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 4/5; 3/9] END ....batch_size=10, epochs=100;, score=0.654 total time=  12.0s
# [CV 5/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 5/5; 3/9] END ....batch_size=10, epochs=100;, score=0.719 total time=  17.1s
# [CV 1/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 1/5; 4/9] END .....batch_size=20, epochs=10;, score=0.695 total time=   1.6s
# [CV 2/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 2/5; 4/9] END .....batch_size=20, epochs=10;, score=0.688 total time=   1.6s
# [CV 3/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 3/5; 4/9] END .....batch_size=20, epochs=10;, score=0.747 total time=   1.5s
# [CV 4/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 4/5; 4/9] END .....batch_size=20, epochs=10;, score=0.771 total time=   1.5s
# [CV 5/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 5/5; 4/9] END .....batch_size=20, epochs=10;, score=0.745 total time=   1.7s
# [CV 1/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 1/5; 5/9] END .....batch_size=20, epochs=50;, score=0.721 total time=   3.4s
# [CV 2/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 2/5; 5/9] END .....batch_size=20, epochs=50;, score=0.675 total time=   5.3s
# [CV 3/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 3/5; 5/9] END .....batch_size=20, epochs=50;, score=0.747 total time=   3.4s
# [CV 4/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 4/5; 5/9] END .....batch_size=20, epochs=50;, score=0.804 total time=   5.2s
# [CV 5/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 5/5; 5/9] END .....batch_size=20, epochs=50;, score=0.706 total time=   3.5s
# [CV 1/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 1/5; 6/9] END ....batch_size=20, epochs=100;, score=0.740 total time=   5.8s
# [CV 2/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 2/5; 6/9] END ....batch_size=20, epochs=100;, score=0.662 total time=   6.0s
# [CV 3/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 3/5; 6/9] END ....batch_size=20, epochs=100;, score=0.695 total time=   6.9s
# [CV 4/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 4/5; 6/9] END ....batch_size=20, epochs=100;, score=0.810 total time=   6.4s
# [CV 5/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 5/5; 6/9] END ....batch_size=20, epochs=100;, score=0.778 total time=   6.8s
# [CV 1/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 1/5; 7/9] END .....batch_size=40, epochs=10;, score=0.734 total time=   2.0s
# [CV 2/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 2/5; 7/9] END .....batch_size=40, epochs=10;, score=0.695 total time=   1.3s
# [CV 3/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 3/5; 7/9] END .....batch_size=40, epochs=10;, score=0.779 total time=   1.7s
# [CV 4/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 4/5; 7/9] END .....batch_size=40, epochs=10;, score=0.810 total time=   1.7s
# [CV 5/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 5/5; 7/9] END .....batch_size=40, epochs=10;, score=0.797 total time=   1.8s
# [CV 1/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 1/5; 8/9] END .....batch_size=40, epochs=50;, score=0.727 total time=   2.8s
# [CV 2/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 2/5; 8/9] END .....batch_size=40, epochs=50;, score=0.675 total time=   2.5s
# [CV 3/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 3/5; 8/9] END .....batch_size=40, epochs=50;, score=0.727 total time=   2.9s
# [CV 4/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 4/5; 8/9] END .....batch_size=40, epochs=50;, score=0.712 total time=   2.2s
# [CV 5/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 5/5; 8/9] END .....batch_size=40, epochs=50;, score=0.765 total time=   3.7s
# [CV 1/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 1/5; 9/9] END ....batch_size=40, epochs=100;, score=0.688 total time=   3.6s
# [CV 2/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 2/5; 9/9] END ....batch_size=40, epochs=100;, score=0.617 total time=   3.8s
# [CV 3/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 3/5; 9/9] END ....batch_size=40, epochs=100;, score=0.740 total time=   3.9s
# [CV 4/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 4/5; 9/9] END ....batch_size=40, epochs=100;, score=0.778 total time=   4.0s
# [CV 5/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 5/5; 9/9] END ....batch_size=40, epochs=100;, score=0.732 total time=   3.9s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.763127076625824, using {'batch_size': 40, 'epochs': 10}
# 0.7214752674102783,0.044695224877655676 with: {'batch_size': 10, 'epochs': 10}
# 0.6720227479934693,0.05414500891650068 with: {'batch_size': 10, 'epochs': 50}
# 0.7134708404541016,0.03850307417562114 with: {'batch_size': 10, 'epochs': 100}
# 0.7292420148849488,0.03219698351831014 with: {'batch_size': 20, 'epochs': 10}
# 0.7305322289466858,0.0433583421979401 with: {'batch_size': 20, 'epochs': 50}
# 0.7371275901794434,0.053710793927879356 with: {'batch_size': 20, 'epochs': 100}
# 0.763127076625824,0.04290166141845034 with: {'batch_size': 40, 'epochs': 10}
# 0.7213988780975342,0.02880272518011056 with: {'batch_size': 40, 'epochs': 50}
# 0.7110517024993896,0.05500953284258166 with: {'batch_size': 40, 'epochs': 100}

# %% [markdown]
# #### Tuning of Hyperparameters:- Learning rate and Drop out rate

# %%
from keras.layers import Dropout

# Defining the model

def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    optimizer = adam_v2.Adam(learning_rate=0.1)
    model.compile(loss = 'binary_crossentropy',optimizer = optimizer,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]

# Make a dictionary of the grid search parameters

param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 1/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.734 total time=   1.4s
# [CV 2/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 2/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.682 total time=   1.7s
# [CV 3/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 3/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.773 total time=   2.0s
# [CV 4/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 4/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.719 total time=   1.8s
# [CV 5/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 5/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.778 total time=   1.4s
# [CV 1/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 1/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.740 total time=   1.5s
# [CV 2/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 2/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.708 total time=   1.4s
# [CV 3/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 3/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.734 total time=   1.6s
# [CV 4/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 4/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.843 total time=   2.1s
# [CV 5/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 5/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.647 total time=   1.6s
# [CV 1/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 1/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.727 total time=   2.3s
# [CV 2/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 2/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.740 total time=   1.8s
# [CV 3/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 3/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.747 total time=   1.4s
# [CV 4/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 4/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.745 total time=   1.7s
# [CV 5/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 5/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.784 total time=   1.5s
# [CV 1/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 1/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.760 total time=   1.8s
# [CV 2/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 2/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.701 total time=   1.5s
# [CV 3/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 3/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.630 total time=   1.9s
# [CV 4/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 4/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.810 total time=   2.2s
# [CV 5/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 5/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.745 total time=   1.7s
# [CV 1/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 1/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.708 total time=   1.8s
# [CV 2/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 2/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.714 total time=   1.7s
# [CV 3/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 3/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.773 total time=   2.1s
# [CV 4/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 4/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.837 total time=   2.1s
# [CV 5/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 5/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.791 total time=   1.7s
# [CV 1/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 1/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.708 total time=   1.6s
# [CV 2/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 2/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.669 total time=   2.0s
# [CV 3/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 3/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.760 total time=   1.5s
# [CV 4/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 4/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.752 total time=   1.9s
# [CV 5/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 5/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.725 total time=   1.6s
# [CV 1/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 1/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.760 total time=   1.6s
# [CV 2/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 2/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.701 total time=   1.5s
# [CV 3/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 3/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.779 total time=   1.6s
# [CV 4/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 4/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.732 total time=   1.7s
# [CV 5/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 5/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.647 total time=   1.8s
# [CV 1/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 1/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.773 total time=   1.4s
# [CV 2/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 2/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.721 total time=   1.5s
# [CV 3/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 3/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.773 total time=   1.8s
# [CV 4/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 4/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.804 total time=   1.7s
# [CV 5/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 5/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.745 total time=   1.7s
# [CV 1/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 1/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.740 total time=   1.4s
# [CV 2/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 2/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.682 total time=   1.6s
# [CV 3/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 3/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.747 total time=   1.8s
# [CV 4/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 4/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.830 total time=   2.0s
# [CV 5/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 5/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.758 total time=   1.7s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7644512414932251, using {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.7370087504386902,0.035553909551028995 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.734402871131897,0.06355309960228862 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.7487395167350769,0.019054967476967947 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# 0.7292929291725159,0.060717549526274846 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# 0.7644512414932251,0.048369052955728 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.7226975679397583,0.032683431038086026 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# 0.7238689422607422,0.04653239681175568 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# 0.7630506753921509,0.028166909455554227 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.7514133095741272,0.04737382656570529 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# #### Tuning of Hyperparameters:- Activation Function and Kernel Initializer

# %%
# Defining the model

def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    optimizer = adam_v2.Adam(learning_rate=0.1)
    model.compile(loss = 'binary_crossentropy',optimizer = optimizer,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']

# Make a dictionary of the grid search parameters
param_grids = dict(activation_function = activation_function,init = init)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 1/5; 1/12] END activation_function=softmax, init=uniform;, score=0.701 total time=   1.5s
# [CV 2/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 2/5; 1/12] END activation_function=softmax, init=uniform;, score=0.656 total time=   1.8s
# [CV 3/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 3/5; 1/12] END activation_function=softmax, init=uniform;, score=0.753 total time=   1.9s
# [CV 4/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 4/5; 1/12] END activation_function=softmax, init=uniform;, score=0.791 total time=   2.0s
# [CV 5/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 5/5; 1/12] END activation_function=softmax, init=uniform;, score=0.765 total time=   1.6s
# [CV 1/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 1/5; 2/12] END activation_function=softmax, init=normal;, score=0.734 total time=   2.0s
# [CV 2/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 2/5; 2/12] END activation_function=softmax, init=normal;, score=0.727 total time=   1.7s
# [CV 3/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 3/5; 2/12] END activation_function=softmax, init=normal;, score=0.753 total time=   1.9s
# [CV 4/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 4/5; 2/12] END activation_function=softmax, init=normal;, score=0.810 total time=   1.8s
# [CV 5/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 5/5; 2/12] END activation_function=softmax, init=normal;, score=0.758 total time=   2.0s
# [CV 1/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 1/5; 3/12] END activation_function=softmax, init=zero;, score=0.721 total time=   1.8s
# [CV 2/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 2/5; 3/12] END activation_function=softmax, init=zero;, score=0.695 total time=   1.6s
# [CV 3/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 3/5; 3/12] END activation_function=softmax, init=zero;, score=0.786 total time=   1.8s
# [CV 4/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 4/5; 3/12] END activation_function=softmax, init=zero;, score=0.817 total time=   2.2s
# [CV 5/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 5/5; 3/12] END activation_function=softmax, init=zero;, score=0.765 total time=   1.9s
# [CV 1/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 1/5; 4/12] END activation_function=relu, init=uniform;, score=0.747 total time=   1.8s
# [CV 2/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 2/5; 4/12] END activation_function=relu, init=uniform;, score=0.734 total time=   2.0s
# [CV 3/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 3/5; 4/12] END activation_function=relu, init=uniform;, score=0.766 total time=   1.6s
# [CV 4/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 4/5; 4/12] END activation_function=relu, init=uniform;, score=0.765 total time=   1.8s
# [CV 5/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 5/5; 4/12] END activation_function=relu, init=uniform;, score=0.758 total time=   1.7s
# [CV 1/5; 5/12] START activation_function=relu, init=normal......................
# [CV 1/5; 5/12] END activation_function=relu, init=normal;, score=0.695 total time=   1.6s
# [CV 2/5; 5/12] START activation_function=relu, init=normal......................
# [CV 2/5; 5/12] END activation_function=relu, init=normal;, score=0.649 total time=   1.7s
# [CV 3/5; 5/12] START activation_function=relu, init=normal......................
# [CV 3/5; 5/12] END activation_function=relu, init=normal;, score=0.740 total time=   1.8s
# [CV 4/5; 5/12] START activation_function=relu, init=normal......................
# [CV 4/5; 5/12] END activation_function=relu, init=normal;, score=0.830 total time=   1.8s
# [CV 5/5; 5/12] START activation_function=relu, init=normal......................
# [CV 5/5; 5/12] END activation_function=relu, init=normal;, score=0.765 total time=   1.8s
# [CV 1/5; 6/12] START activation_function=relu, init=zero........................
# [CV 1/5; 6/12] END activation_function=relu, init=zero;, score=0.649 total time=   1.7s
# [CV 2/5; 6/12] START activation_function=relu, init=zero........................
# [CV 2/5; 6/12] END activation_function=relu, init=zero;, score=0.584 total time=   1.4s
# [CV 3/5; 6/12] START activation_function=relu, init=zero........................
# [CV 3/5; 6/12] END activation_function=relu, init=zero;, score=0.630 total time=   1.5s
# [CV 4/5; 6/12] START activation_function=relu, init=zero........................
# [CV 4/5; 6/12] END activation_function=relu, init=zero;, score=0.745 total time=   1.5s
# [CV 5/5; 6/12] START activation_function=relu, init=zero........................
# [CV 5/5; 6/12] END activation_function=relu, init=zero;, score=0.647 total time=   1.9s
# [CV 1/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 1/5; 7/12] END activation_function=tanh, init=uniform;, score=0.753 total time=   1.5s
# [CV 2/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 2/5; 7/12] END activation_function=tanh, init=uniform;, score=0.747 total time=   1.4s
# [CV 3/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 3/5; 7/12] END activation_function=tanh, init=uniform;, score=0.786 total time=   1.7s
# [CV 4/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 4/5; 7/12] END activation_function=tanh, init=uniform;, score=0.810 total time=   1.5s
# [CV 5/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 5/5; 7/12] END activation_function=tanh, init=uniform;, score=0.752 total time=   1.5s
# [CV 1/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 1/5; 8/12] END activation_function=tanh, init=normal;, score=0.727 total time=   1.5s
# [CV 2/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 2/5; 8/12] END activation_function=tanh, init=normal;, score=0.695 total time=   1.5s
# [CV 3/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 3/5; 8/12] END activation_function=tanh, init=normal;, score=0.779 total time=   1.8s
# [CV 4/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 4/5; 8/12] END activation_function=tanh, init=normal;, score=0.830 total time=   1.7s
# [CV 5/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 5/5; 8/12] END activation_function=tanh, init=normal;, score=0.745 total time=   1.4s
# [CV 1/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 1/5; 9/12] END activation_function=tanh, init=zero;, score=0.649 total time=   1.4s
# [CV 2/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 2/5; 9/12] END activation_function=tanh, init=zero;, score=0.584 total time=   1.6s
# [CV 3/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 3/5; 9/12] END activation_function=tanh, init=zero;, score=0.630 total time=   1.5s
# [CV 4/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 4/5; 9/12] END activation_function=tanh, init=zero;, score=0.745 total time=   1.5s
# [CV 5/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 5/5; 9/12] END activation_function=tanh, init=zero;, score=0.647 total time=   1.6s
# [CV 1/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 1/5; 10/12] END activation_function=linear, init=uniform;, score=0.760 total time=   1.8s
# [CV 2/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 2/5; 10/12] END activation_function=linear, init=uniform;, score=0.701 total time=   1.6s
# [CV 3/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 3/5; 10/12] END activation_function=linear, init=uniform;, score=0.779 total time=   1.8s
# [CV 4/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 4/5; 10/12] END activation_function=linear, init=uniform;, score=0.843 total time=   1.7s
# [CV 5/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 5/5; 10/12] END activation_function=linear, init=uniform;, score=0.765 total time=   1.7s
# [CV 1/5; 11/12] START activation_function=linear, init=normal...................
# [CV 1/5; 11/12] END activation_function=linear, init=normal;, score=0.747 total time=   1.5s
# [CV 2/5; 11/12] START activation_function=linear, init=normal...................
# [CV 2/5; 11/12] END activation_function=linear, init=normal;, score=0.617 total time=   1.6s
# [CV 3/5; 11/12] START activation_function=linear, init=normal...................
# [CV 3/5; 11/12] END activation_function=linear, init=normal;, score=0.753 total time=   1.5s
# [CV 4/5; 11/12] START activation_function=linear, init=normal...................
# [CV 4/5; 11/12] END activation_function=linear, init=normal;, score=0.830 total time=   1.9s
# [CV 5/5; 11/12] START activation_function=linear, init=normal...................
# [CV 5/5; 11/12] END activation_function=linear, init=normal;, score=0.771 total time=   1.8s
# [CV 1/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 1/5; 12/12] END activation_function=linear, init=zero;, score=0.649 total time=   1.5s
# [CV 2/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 2/5; 12/12] END activation_function=linear, init=zero;, score=0.584 total time=   1.4s
# [CV 3/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 3/5; 12/12] END activation_function=linear, init=zero;, score=0.630 total time=   1.7s
# [CV 4/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 4/5; 12/12] END activation_function=linear, init=zero;, score=0.745 total time=   1.4s
# [CV 5/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 5/5; 12/12] END activation_function=linear, init=zero;, score=0.647 total time=   1.4s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7696205735206604, using {'activation_function': 'linear', 'init': 'uniform'}
# 0.7331890344619751,0.048414042638376 with: {'activation_function': 'softmax', 'init': 'uniform'}
# 0.7565826416015625,0.0293114599139131 with: {'activation_function': 'softmax', 'init': 'normal'}
# 0.7565996170043945,0.043960076335449884 with: {'activation_function': 'softmax', 'init': 'zero'}
# 0.7539258241653443,0.012194760954141725 with: {'activation_function': 'relu', 'init': 'uniform'}
# 0.7358373761177063,0.061474316282015294 with: {'activation_function': 'relu', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'relu', 'init': 'zero'}
# 0.7695611596107483,0.024662437884767498 with: {'activation_function': 'tanh', 'init': 'uniform'}
# 0.7552924275398254,0.046284532387723974 with: {'activation_function': 'tanh', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'tanh', 'init': 'zero'}
# 0.7696205735206604,0.04535751116935031 with: {'activation_function': 'linear', 'init': 'uniform'}
# 0.7436380624771118,0.06985771230268006 with: {'activation_function': 'linear', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'linear', 'init': 'zero'}

# %% [markdown]
# #### Tuning of Hyperparameter :-Number of Neurons in activation layer

# %%
# Defining the model

def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    optimizer = adam_v2.Adam(learning_rate=0.1)
    model.compile(loss = 'binary_crossentropy',optimizer = optimizer,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 1/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.766 total time=   2.5s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 2/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.682 total time=   2.2s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 3/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.779 total time=   2.2s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 4/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.850 total time=   1.6s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 5/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.771 total time=   1.8s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 1/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.734 total time=   1.5s
# [CV 2/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 2/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.740 total time=   1.9s
# [CV 3/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 3/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.721 total time=   1.7s
# [CV 4/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 4/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.830 total time=   2.5s
# [CV 5/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 5/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.771 total time=   1.7s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 1/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.760 total time=   2.6s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 2/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.727 total time=   1.9s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 3/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.734 total time=   1.9s
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 4/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.804 total time=   1.6s
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 5/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.739 total time=   2.0s
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 1/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.734 total time=   1.7s
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 2/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.721 total time=   2.0s
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 3/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.747 total time=   1.7s
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 4/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.817 total time=   1.7s
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 5/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.758 total time=   1.4s
# [CV 1/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 1/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.753 total time=   1.8s
# [CV 2/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 2/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.695 total time=   1.4s
# [CV 3/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 3/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.747 total time=   1.7s
# [CV 4/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 4/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.830 total time=   1.5s
# [CV 5/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 5/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.712 total time=   2.0s
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 1/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.734 total time=   1.6s
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 2/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.682 total time=   1.5s
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 3/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.786 total time=   1.4s
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 4/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.817 total time=   1.4s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 5/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.778 total time=   1.7s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 1/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.734 total time=   1.4s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 2/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.721 total time=   1.5s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 3/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.747 total time=   1.9s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 4/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.797 total time=   1.5s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 5/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.752 total time=   1.5s
# [CV 1/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 1/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.766 total time=   1.4s
# [CV 2/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 2/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.682 total time=   1.8s
# [CV 3/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 3/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.740 total time=   1.5s
# [CV 4/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 4/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.850 total time=   1.6s
# [CV 5/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 5/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.758 total time=   1.5s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 1/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.721 total time=   2.0s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 2/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.669 total time=   1.6s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 3/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.779 total time=   1.5s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 4/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.830 total time=   1.8s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 5/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.752 total time=   1.5s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7696375489234925, using {'neuron1': 4, 'neuron2': 2}
# 0.7696375489234925,0.05333656377526333 with: {'neuron1': 4, 'neuron2': 2}
# 0.7592224955558777,0.039111805261255454 with: {'neuron1': 4, 'neuron2': 4}
# 0.7526525855064392,0.027850011285931908 with: {'neuron1': 4, 'neuron2': 8}
# 0.7552924394607544,0.03329490229020726 with: {'neuron1': 8, 'neuron2': 2}
# 0.7474577784538269,0.04660060009598376 with: {'neuron1': 8, 'neuron2': 4}
# 0.7592139959335327,0.04695326553592345 with: {'neuron1': 8, 'neuron2': 8}
# 0.750063681602478,0.02598451967593131 with: {'neuron1': 16, 'neuron2': 2}
# 0.7592309713363647,0.054004831524371695 with: {'neuron1': 16, 'neuron2': 4}
# 0.7501061081886291,0.05423866097041805 with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# #### Training model with optimum values of Hyperparameters

# %%
from sklearn.metrics import classification_report, accuracy_score


# Defining the model

def create_model():
    model = Sequential()
    model.add(Dense(16,input_dim = 8,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 16,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = adam_v2.Adam(learning_rate=0.1)

    #adam = Adam(lr = 0.001) #sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Fitting the model

model.fit(X_standardized,y)

# Predicting using trained model

y_predict = model.predict(X_standardized)

# Printing the metrics
print(accuracy_score(y,y_predict))
# Out:
# 0.7864583333333334

# %% [markdown]
# # Hyperparameters all at once

# %% [markdown]
# The hyperparameter optimization was carried out by taking 2 hyperparameters at once. We may have missed the best values. The performance can be further improved by finding the optimum values of hyperparameters all at once given by the code snippet below.
# #### This process is computationally expensive.

# %%
def create_model(learning_rate,dropout_rate,activation_function,init,neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = adam_v2.Adam(learning_rate=0.1)

    #adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0)

# Define the grid search parameters

batch_size = [10,20,40]
epochs = [10,50,100]
learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']
neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(batch_size = batch_size,epochs = epochs,learning_rate = learning_rate,dropout_rate = dropout_rate,
                   activation_function = activation_function,init = init,neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)

# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Fitting 5 folds for each of 8748 candidates, totalling 43740 fits
# [CV 1/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [CV 1/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2;, score=0.669 total time=   3.0s
# [CV 2/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [CV 2/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2;, score=0.688 total time=   2.6s
# [CV 3/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [CV 3/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2;, score=0.714 total time=   3.0s
# [CV 4/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [CV 4/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2;, score=0.791 total time=   2.3s
# [CV 5/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [CV 5/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2;, score=0.732 total time=   2.4s
# [CV 1/5; 2/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [CV 1/5; 2/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4;, score=0.701 total time=   2.9s
# [CV 2/5; 2/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [CV 2/5; 2/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4;, score=0.734 total time=   2.1s
# [CV 3/5; 2/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [CV 3/5; 2/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4;, score=0.714 total time=   2.2s
# [CV 4/5; 2/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [CV 4/5; 2/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4;, score=0.693 total time=   2.7s
# [CV 5/5; 2/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [CV 5/5; 2/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4;, score=0.765 total time=   2.5s
# [CV 1/5; 3/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV 1/5; 3/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8;, score=0.727 total time=   2.9s
# [CV 2/5; 3/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV 2/5; 3/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8;, score=0.701 total time=   2.2s
# [CV 3/5; 3/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV 3/5; 3/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8;, score=0.786 total time=   2.1s
# [CV 4/5; 3/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV 4/5; 3/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8;, score=0.810 total time=   2.1s
# [CV 5/5; 3/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV 5/5; 3/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8;, score=0.745 total time=   3.1s
# [CV 1/5; 4/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV 1/5; 4/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2;, score=0.721 total time=   2.8s
# [CV 2/5; 4/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV 2/5; 4/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2;, score=0.734 total time=   3.8s
# [CV 3/5; 4/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV 3/5; 4/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2;, score=0.766 total time=   3.0s
# [CV 4/5; 4/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV 4/5; 4/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2;, score=0.824 total time=   4.1s
# [CV 5/5; 4/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV 5/5; 4/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2;, score=0.758 total time=   2.7s
# [CV 1/5; 5/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV 1/5; 5/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4;, score=0.714 total time=   3.7s
# [CV 2/5; 5/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV 2/5; 5/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4;, score=0.688 total time=   2.7s
# [CV 3/5; 5/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV 3/5; 5/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4;, score=0.701 total time=   2.8s
# [CV 4/5; 5/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV 4/5; 5/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4;, score=0.771 total time=   2.1s
# [CV 5/5; 5/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV 5/5; 5/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4;, score=0.752 total time=   2.1s
# [CV 1/5; 6/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV 1/5; 6/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8;, score=0.753 total time=   2.1s
# [CV 2/5; 6/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV 2/5; 6/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8;, score=0.701 total time=   2.4s
# [CV 3/5; 6/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV 3/5; 6/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8;, score=0.747 total time=   2.2s
# [CV 4/5; 6/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV 4/5; 6/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8;, score=0.843 total time=   2.7s
# [CV 5/5; 6/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV 5/5; 6/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8;, score=0.745 total time=   2.1s
# [CV 1/5; 7/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV 1/5; 7/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2;, score=0.682 total time=   2.0s
# [CV 2/5; 7/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV 2/5; 7/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2;, score=0.695 total time=   2.8s
# [CV 3/5; 7/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV 3/5; 7/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2;, score=0.747 total time=   2.1s
# [CV 4/5; 7/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV 4/5; 7/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2;, score=0.797 total time=   2.8s
# [CV 5/5; 7/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV 5/5; 7/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2;, score=0.752 total time=   2.1s
# [CV 1/5; 8/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV 1/5; 8/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4;, score=0.747 total time=   2.4s
# [CV 2/5; 8/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV 2/5; 8/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4;, score=0.662 total time=   2.1s
# [CV 3/5; 8/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV 3/5; 8/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4;, score=0.753 total time=   2.1s
# [CV 4/5; 8/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV 4/5; 8/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4;, score=0.667 total time=   2.1s
# [CV 5/5; 8/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV 5/5; 8/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4;, score=0.712 total time=   2.1s
# [CV 1/5; 9/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV 1/5; 9/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8;, score=0.695 total time=   2.8s
# [CV 2/5; 9/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV 2/5; 9/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8;, score=0.766 total time=   2.7s
# [CV 3/5; 9/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV 3/5; 9/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8;, score=0.766 total time=   2.1s
# [CV 4/5; 9/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV 4/5; 9/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8;, score=0.804 total time=   2.8s
# [CV 5/5; 9/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV 5/5; 9/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8;, score=0.732 total time=   2.5s
# [CV 1/5; 10/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 1/5; 10/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2;, score=0.740 total time=   2.1s
# [CV 2/5; 10/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 2/5; 10/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2;, score=0.688 total time=   2.1s
# [CV 3/5; 10/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 3/5; 10/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2;, score=0.786 total time=   2.1s
# [CV 4/5; 10/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 4/5; 10/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2;, score=0.739 total time=   2.1s
# [CV 5/5; 10/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 5/5; 10/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2;, score=0.712 total time=   2.0s
# [CV 1/5; 11/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 1/5; 11/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4;, score=0.734 total time=   2.9s
# [CV 2/5; 11/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 2/5; 11/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4;, score=0.695 total time=   2.8s
# [CV 3/5; 11/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 3/5; 11/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4;, score=0.766 total time=   2.4s
# [CV 4/5; 11/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 4/5; 11/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4;, score=0.830 total time=   2.1s
# [CV 5/5; 11/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 5/5; 11/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4;, score=0.765 total time=   2.1s
# [CV 1/5; 12/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV 1/5; 12/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8;, score=0.701 total time=   2.1s
# [CV 2/5; 12/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV 2/5; 12/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8;, score=0.701 total time=   2.1s
# [CV 3/5; 12/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV 3/5; 12/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8;, score=0.760 total time=   2.7s
# [CV 4/5; 12/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV 4/5; 12/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8;, score=0.837 total time=   2.4s
# [CV 5/5; 12/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV 5/5; 12/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8;, score=0.758 total time=   2.1s
# [CV 1/5; 13/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 1/5; 13/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2;, score=0.721 total time=   2.5s
# [CV 2/5; 13/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 2/5; 13/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2;, score=0.662 total time=   2.1s
# [CV 3/5; 13/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 3/5; 13/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2;, score=0.747 total time=   2.8s
# [CV 4/5; 13/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 4/5; 13/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2;, score=0.804 total time=   2.8s
# [CV 5/5; 13/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 5/5; 13/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2;, score=0.732 total time=   2.2s
# [CV 1/5; 14/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 1/5; 14/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4;, score=0.701 total time=   2.1s
# [CV 2/5; 14/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 2/5; 14/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4;, score=0.682 total time=   2.1s
# [CV 3/5; 14/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 3/5; 14/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4;, score=0.760 total time=   2.8s
# [CV 4/5; 14/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 4/5; 14/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4;, score=0.732 total time=   2.1s
# [CV 5/5; 14/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 5/5; 14/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4;, score=0.778 total time=   3.1s
# [CV 1/5; 15/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV 1/5; 15/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.714 total time=   2.1s
# [CV 2/5; 15/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV 2/5; 15/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.701 total time=   2.5s
# [CV 3/5; 15/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV 3/5; 15/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.727 total time=   2.0s
# [CV 4/5; 15/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV 4/5; 15/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.791 total time=   2.2s
# [CV 5/5; 15/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV 5/5; 15/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.739 total time=   2.1s
# [CV 1/5; 16/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV 1/5; 16/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2;, score=0.760 total time=   2.9s
# [CV 2/5; 16/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV 2/5; 16/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2;, score=0.701 total time=   2.2s
# [CV 3/5; 16/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV 3/5; 16/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2;, score=0.734 total time=   2.5s
# [CV 4/5; 16/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV 4/5; 16/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2;, score=0.771 total time=   2.1s
# [CV 5/5; 16/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV 5/5; 16/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2;, score=0.739 total time=   2.1s
# [CV 1/5; 17/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV 1/5; 17/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4;, score=0.688 total time=   2.1s
# [CV 2/5; 17/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV 2/5; 17/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4;, score=0.656 total time=   2.1s
# [CV 3/5; 17/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV 3/5; 17/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4;, score=0.766 total time=   2.8s
# [CV 4/5; 17/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV 4/5; 17/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4;, score=0.595 total time=   2.9s
# [CV 5/5; 17/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV 5/5; 17/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4;, score=0.771 total time=   2.2s
# [CV 1/5; 18/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV 1/5; 18/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8;, score=0.727 total time=   2.2s
# [CV 2/5; 18/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV 2/5; 18/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8;, score=0.714 total time=   2.5s
# [CV 3/5; 18/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV 3/5; 18/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8;, score=0.760 total time=   2.8s
# [CV 4/5; 18/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV 4/5; 18/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8;, score=0.771 total time=   2.0s
# [CV 5/5; 18/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV 5/5; 18/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8;, score=0.752 total time=   2.1s
# [CV 1/5; 19/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 1/5; 19/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=0.714 total time=   2.0s
# [CV 2/5; 19/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 2/5; 19/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=0.675 total time=   2.1s
# [CV 3/5; 19/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 3/5; 19/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=0.682 total time=   2.1s
# [CV 4/5; 19/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 4/5; 19/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=0.654 total time=   2.9s
# [CV 5/5; 19/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 5/5; 19/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=0.752 total time=   2.0s
# [CV 1/5; 20/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 1/5; 20/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4;, score=0.708 total time=   2.3s
# [CV 2/5; 20/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 2/5; 20/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4;, score=0.669 total time=   2.7s
# [CV 3/5; 20/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 3/5; 20/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4;, score=0.779 total time=   2.9s
# [CV 4/5; 20/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 4/5; 20/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4;, score=0.830 total time=   2.1s
# [CV 5/5; 20/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 5/5; 20/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4;, score=0.771 total time=   2.1s
# [CV 1/5; 21/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV 1/5; 21/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8;, score=0.695 total time=   2.1s
# [CV 2/5; 21/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV 2/5; 21/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8;, score=0.675 total time=   2.1s
# [CV 3/5; 21/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV 3/5; 21/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8;, score=0.740 total time=   2.2s
# [CV 4/5; 21/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV 4/5; 21/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8;, score=0.856 total time=   2.5s
# [CV 5/5; 21/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV 5/5; 21/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8;, score=0.732 total time=   1.4s
# [CV 1/5; 22/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 1/5; 22/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2;, score=0.669 total time=   2.1s
# [CV 2/5; 22/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 2/5; 22/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2;, score=0.721 total time=   1.7s
# [CV 3/5; 22/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 3/5; 22/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2;, score=0.766 total time=   2.3s
# [CV 4/5; 22/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 4/5; 22/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2;, score=0.837 total time=   2.7s
# [CV 5/5; 22/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 5/5; 22/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2;, score=0.712 total time=   2.6s
# [CV 1/5; 23/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 1/5; 23/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4;, score=0.727 total time=   2.1s
# [CV 2/5; 23/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 2/5; 23/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4;, score=0.656 total time=   2.0s
# [CV 3/5; 23/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 3/5; 23/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4;, score=0.740 total time=   2.5s
# [CV 4/5; 23/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 4/5; 23/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4;, score=0.791 total time=   2.8s
# [CV 5/5; 23/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 5/5; 23/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4;, score=0.765 total time=   2.4s
# [CV 1/5; 24/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV 1/5; 24/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8;, score=0.695 total time=   2.8s
# [CV 2/5; 24/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV 2/5; 24/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8;, score=0.662 total time=   2.6s
# [CV 3/5; 24/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV 3/5; 24/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8;, score=0.773 total time=   3.3s
# [CV 4/5; 24/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV 4/5; 24/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8;, score=0.699 total time=   3.3s
# [CV 5/5; 24/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV 5/5; 24/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8;, score=0.739 total time=   2.2s
# [CV 1/5; 25/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV 1/5; 25/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2;, score=0.734 total time=   2.2s
# [CV 2/5; 25/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV 2/5; 25/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2;, score=0.682 total time=   2.6s
# [CV 3/5; 25/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV 3/5; 25/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2;, score=0.747 total time=   2.2s
# [CV 4/5; 25/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV 4/5; 25/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2;, score=0.719 total time=   2.4s
# [CV 5/5; 25/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV 5/5; 25/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2;, score=0.791 total time=   2.2s
# [CV 1/5; 26/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV 1/5; 26/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4;, score=0.708 total time=   3.0s
# [CV 2/5; 26/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV 2/5; 26/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4;, score=0.669 total time=   3.1s
# [CV 3/5; 26/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV 3/5; 26/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4;, score=0.747 total time=   3.7s
# [CV 4/5; 26/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV 4/5; 26/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4;, score=0.830 total time=   2.7s
# [CV 5/5; 26/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV 5/5; 26/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4;, score=0.745 total time=   2.7s
# [CV 1/5; 27/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV 1/5; 27/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8;, score=0.753 total time=   2.2s
# [CV 2/5; 27/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV 2/5; 27/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8;, score=0.701 total time=   2.9s
# [CV 3/5; 27/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV 3/5; 27/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8;, score=0.753 total time=   2.1s
# [CV 4/5; 27/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV 4/5; 27/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8;, score=0.810 total time=   2.1s
# [CV 5/5; 27/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV 5/5; 27/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8;, score=0.745 total time=   2.9s
# [CV 1/5; 28/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV 1/5; 28/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2;, score=0.695 total time=   2.4s
# [CV 2/5; 28/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV 2/5; 28/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2;, score=0.669 total time=   2.7s
# [CV 3/5; 28/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV 3/5; 28/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2;, score=0.753 total time=   2.1s
# [CV 4/5; 28/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV 4/5; 28/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2;, score=0.843 total time=   2.7s
# [CV 5/5; 28/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV 5/5; 28/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2;, score=0.771 total time=   2.2s
# [CV 1/5; 29/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4
# [CV 1/5; 29/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4;, score=0.675 total time=   2.2s
# [CV 2/5; 29/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4
# [CV 2/5; 29/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4;, score=0.701 total time=   2.6s
# [CV 3/5; 29/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4
# [CV 3/5; 29/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4;, score=0.734 total time=   1.7s
# [CV 4/5; 29/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4
# [CV 4/5; 29/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4;, score=0.660 total time=   1.9s
# [CV 5/5; 29/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4
# [CV 5/5; 29/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4;, score=0.725 total time=   2.2s
# [CV 1/5; 30/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8
# [CV 1/5; 30/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8;, score=0.701 total time=   2.2s
# [CV 2/5; 30/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8
# [CV 2/5; 30/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8;, score=0.662 total time=   2.1s
# [CV 3/5; 30/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8
# [CV 3/5; 30/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8;, score=0.727 total time=   3.0s
# [CV 4/5; 30/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8
# [CV 4/5; 30/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8;, score=0.725 total time=   2.1s
# [CV 5/5; 30/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8
# [CV 5/5; 30/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8;, score=0.732 total time=   2.1s
# [CV 1/5; 31/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2
# [CV 1/5; 31/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2;, score=0.701 total time=   2.4s
# [CV 2/5; 31/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2
# [CV 2/5; 31/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2;, score=0.682 total time=   2.6s
# [CV 3/5; 31/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2
# [CV 3/5; 31/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2;, score=0.734 total time=   2.3s
# [CV 4/5; 31/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2
# [CV 4/5; 31/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2;, score=0.804 total time=   2.1s
# [CV 5/5; 31/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2
# [CV 5/5; 31/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2;, score=0.719 total time=   2.4s
# [CV 1/5; 32/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4
# [CV 1/5; 32/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4;, score=0.721 total time=   2.3s
# [CV 2/5; 32/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4
# [CV 2/5; 32/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4;, score=0.675 total time=   2.3s
# [CV 3/5; 32/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4
# [CV 3/5; 32/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4;, score=0.747 total time=   2.4s
# [CV 4/5; 32/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4
# [CV 4/5; 32/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4;, score=0.837 total time=   2.4s
# [CV 5/5; 32/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4
# [CV 5/5; 32/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4;, score=0.778 total time=   2.0s
# [CV 1/5; 33/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=8
# [CV 1/5; 33/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=8;, score=0.695 total time=   2.3s
# [CV 2/5; 33/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=8
